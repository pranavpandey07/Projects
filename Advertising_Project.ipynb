# %%
#importing important libraries 
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# This dataset has continuous values in target column (sales) hence it is a problem of regression

# %%
#loading the dataset
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
pd.set_option('display.max_rows',None)   #allowing us to see all the rows of the dataset

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
#dimensions of the dataset
df.shape
# Out:
# (200, 5)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
#statistical summary of the data
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
#All column names of the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
#Renaming the first column
uf=df.rename(columns={"Unnamed: 0": "SrNo"})

# %%
uf
# Out:
#      SrNo     TV  radio  newspaper  sales
# 0       1  230.1   37.8       69.2   22.1
# 1       2   44.5   39.3       45.1   10.4
# 2       3   17.2   45.9       69.3    9.3
# 3       4  151.5   41.3       58.5   18.5
# 4       5  180.8   10.8       58.4   12.9
# 5       6    8.7   48.9       75.0    7.2
# 6       7   57.5   32.8       23.5   11.8
# 7       8  120.2   19.6       11.6   13.2
# 8       9    8.6    2.1        1.0    4.8
# 9      10  199.8    2.6       21.2   10.6
# 10     11   66.1    5.8       24.2    8.6
# 11     12  214.7   24.0        4.0   17.4
# 12     13   23.8   35.1       65.9    9.2
# 13     14   97.5    7.6        7.2    9.7
# 14     15  204.1   32.9       46.0   19.0
# 15     16  195.4   47.7       52.9   22.4
# 16     17   67.8   36.6      114.0   12.5
# 17     18  281.4   39.6       55.8   24.4
# 18     19   69.2   20.5       18.3   11.3
# 19     20  147.3   23.9       19.1   14.6
# 20     21  218.4   27.7       53.4   18.0
# ...

# %%
#checking the null values in the dataset
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# We dont have any null values in dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#visualising the null values in the  dataset
sns.heatmap(uf.isnull())
plt.title("Null values")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Exploratory data analysis

# %%
sns.scatterplot( x=uf["TV"], y=uf["sales"])

# %% [markdown]
# We can see a linear relationship between sales and TV

# %%
sns.scatterplot( x=uf["radio"], y=uf["sales"])

# %% [markdown]
# We can also see that there is some linear relationship present between radio and sales

# %%
sns.scatterplot( x=uf["newspaper"], y=uf["sales"])

# %%
#plotting histogram for various columns
uf.hist(bins=40,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002359A6D2730>,
# ...
#       dtype=object)

# %%
uf['TV'].plot(kind="kde",figsize=(6,6))

# %% [markdown]
# for column TV the data is nearly symmetrically distributed

# %%
uf['radio'].plot(kind="kde",figsize=(6,6))

# %% [markdown]
# Data is approximately  symmetrically  distributed for radio column also

# %%
uf['newspaper'].plot(kind="kde",figsize=(6,6))

# %% [markdown]
# We can see data is skewed in positive side for column newspaper

# %%
uf['sales'].plot(kind="kde",figsize=(6,6))

# %%
#checking skewness for each column
uf.skew()
# Out:
# SrNo         0.000000
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
#plotting box plot for checking outliers
uf.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# There are no considerable outliers present in the dataset hence we do not need to remove it

# %%
#dopping a column
uf.drop('SrNo',axis=1, inplace=True)

# %%
uf
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   10.6
# 10    66.1    5.8       24.2    8.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2    9.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   12.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   15.5
# 24    62.3   12.6       18.3    9.7
# ...

# %%
uf.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# We can see there are skewed data present in the newspaper and sales column hence we should remove it

# %%
#we see the skewness in the dataset. we will remove the skewness using the power_transform function
from sklearn.preprocessing import power_transform
df_new=power_transform(uf)

df_new=pd.DataFrame(df_new,columns=uf.columns)

# %%
df_new.skew()
# Out:
# TV          -0.315199
# radio       -0.242968
# newspaper   -0.077942
# sales       -0.007841
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
obj= StandardScaler()
df_new = obj.fit_transform(df_new)

# %%
df_new
# Out:
# array([[ 9.48674291e-01,  9.62246888e-01,  1.51433531e+00,
#          1.46441197e+00],
#        [-1.19131426e+00,  1.04017880e+00,  7.87682518e-01,
#         -6.50692513e-01],
#        [-1.64775660e+00,  1.37070964e+00,  1.51699753e+00,
#         -8.94549951e-01],
#        [ 1.41020233e-01,  1.14238689e+00,  1.21465643e+00,
#          8.82528036e-01],
#        [ 4.52714928e-01, -7.48650643e-01,  1.21170398e+00,
#         -1.34549801e-01],
#        [-1.82382233e+00,  1.51501853e+00,  1.66502354e+00,
#         -1.39687742e+00],
#        [-1.00249116e+00,  6.93727035e-01, -1.07753498e-01,
#         -3.55780023e-01],
#        [-2.10275002e-01, -1.01585443e-01, -8.44093412e-01,
#         -7.56544391e-02],
#        [-1.82609501e+00, -1.63345378e+00, -2.13259669e+00,
#         -2.05242372e+00],
#        [ 6.47644918e-01, -1.56676988e+00, -2.29003949e-01,
#         -6.07561054e-01],
#        [-8.83773778e-01, -1.20298758e+00, -7.22615630e-02,
#         -1.05614129e+00],
# ...

# %%
#conversion of array into dataframe
df = pd.DataFrame(df_new)

# %%
df
# Out:
#             0         1         2         3
# 0    0.948674  0.962247  1.514335  1.464412
# 1   -1.191314  1.040179  0.787683 -0.650693
# 2   -1.647757  1.370710  1.516998 -0.894550
# 3    0.141020  1.142387  1.214656  0.882528
# 4    0.452715 -0.748651  1.211704 -0.134550
# 5   -1.823822  1.515019  1.665024 -1.396877
# 6   -1.002491  0.693727 -0.107753 -0.355780
# 7   -0.210275 -0.101585 -0.844093 -0.075654
# 8   -1.826095 -1.633454 -2.132597 -2.052424
# 9    0.647645 -1.566770 -0.229004 -0.607561
# 10  -0.883774 -1.202988 -0.072262 -1.056141
# 11   0.797084  0.180726 -1.602619  0.694843
# 12  -1.526416  0.819006  1.425129 -0.917312
# 13  -0.480368 -1.028136 -1.229825 -0.804523
# 14   0.691066  0.699240  0.818606  0.966194
# 15   0.602957  1.457704  1.044323  1.510912
# 16  -0.860800  0.899070  2.529435 -0.214013
# 17   1.435520  1.055631  1.133833  1.814026
# 18  -0.841993 -0.042099 -0.393560 -0.459282
# 19   0.095086  0.174532 -0.346715  0.191784
# ...

# %%
#Renaming the columns of the dataframe
uf=df.rename(columns={0:"Tv",1:"Radio",2:"Newspaper",3:"Sales"})

# %%
uf
# Out:
#            Tv     Radio  Newspaper     Sales
# 0    0.948674  0.962247   1.514335  1.464412
# 1   -1.191314  1.040179   0.787683 -0.650693
# 2   -1.647757  1.370710   1.516998 -0.894550
# 3    0.141020  1.142387   1.214656  0.882528
# 4    0.452715 -0.748651   1.211704 -0.134550
# 5   -1.823822  1.515019   1.665024 -1.396877
# 6   -1.002491  0.693727  -0.107753 -0.355780
# 7   -0.210275 -0.101585  -0.844093 -0.075654
# 8   -1.826095 -1.633454  -2.132597 -2.052424
# 9    0.647645 -1.566770  -0.229004 -0.607561
# 10  -0.883774 -1.202988  -0.072262 -1.056141
# 11   0.797084  0.180726  -1.602619  0.694843
# 12  -1.526416  0.819006   1.425129 -0.917312
# 13  -0.480368 -1.028136  -1.229825 -0.804523
# 14   0.691066  0.699240   0.818606  0.966194
# 15   0.602957  1.457704   1.044323  1.510912
# 16  -0.860800  0.899070   2.529435 -0.214013
# 17   1.435520  1.055631   1.133833  1.814026
# 18  -0.841993 -0.042099  -0.393560 -0.459282
# 19   0.095086  0.174532  -0.346715  0.191784
# ...

# %%
#checking correlation with heatmap
corr_mat=uf.corr()
plt.figure(figsize=[8,8])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# We can see from correlation matrix that sales has very good correlation with TV and Radio

# %%
corr_matrix=uf.corr()
corr_matrix["Sales"].sort_values(ascending=False)
# Out:
# Sales        1.000000
# Tv           0.808657
# Radio        0.542506
# Newspaper    0.196643
# Name: Sales, dtype: float64

# %%
#bifurcating the the columns into x and y for model training
x=uf.drop('Sales',axis=1)
y=uf['Sales']

# %%
x
# Out:
#            Tv     Radio  Newspaper
# 0    0.948674  0.962247   1.514335
# 1   -1.191314  1.040179   0.787683
# 2   -1.647757  1.370710   1.516998
# 3    0.141020  1.142387   1.214656
# 4    0.452715 -0.748651   1.211704
# 5   -1.823822  1.515019   1.665024
# 6   -1.002491  0.693727  -0.107753
# 7   -0.210275 -0.101585  -0.844093
# 8   -1.826095 -1.633454  -2.132597
# 9    0.647645 -1.566770  -0.229004
# 10  -0.883774 -1.202988  -0.072262
# 11   0.797084  0.180726  -1.602619
# 12  -1.526416  0.819006   1.425129
# 13  -0.480368 -1.028136  -1.229825
# 14   0.691066  0.699240   0.818606
# 15   0.602957  1.457704   1.044323
# 16  -0.860800  0.899070   2.529435
# 17   1.435520  1.055631   1.133833
# 18  -0.841993 -0.042099  -0.393560
# 19   0.095086  0.174532  -0.346715
# 20   0.833761  0.403671   1.059965
# 21   1.019586 -1.275673  -0.107753
# 22  -1.727016 -0.357393   0.938757
# 23   0.931098 -0.286311   0.025893
# 24  -0.935698 -0.604311  -0.393560
# 25   1.262909 -1.455058  -0.323726
# ...

# %%
y
# Out:
# 0      1.464412
# 1     -0.650693
# 2     -0.894550
# 3      0.882528
# 4     -0.134550
# 5     -1.396877
# 6     -0.355780
# 7     -0.075654
# 8     -2.052424
# 9     -0.607561
# 10    -1.056141
# 11     0.694843
# 12    -0.917312
# 13    -0.804523
# 14     0.966194
# 15     1.510912
# 16    -0.214013
# 17     1.814026
# 18    -0.459282
# 19     0.191784
# 20     0.797849
# 21    -0.214013
# 22    -1.821784
# 23     0.357789
# 24    -0.804523
# 25    -0.314912
# 26     0.266104
# 27     0.430202
# 28     0.949540
# 29    -0.629083
# 30     1.354798
# 31    -0.335309
# 32    -0.826879
# 33     0.694843
# 34    -0.849335
# 35    -0.154314
# 36     1.961377
# 37     0.210447
# 38    -0.716061
# 39     1.370554
# 40     0.555016
# 41     0.642748
# 42     1.243564
# 43    -0.134550
# 44    -1.079671
# 45     0.247607
# 46    -0.607561
# 47     1.633562
# 48     0.229055
# 49    -0.804523
# 50    -0.438426
# 51    -0.586126
# 52     1.541757
# 53     1.323185
# 54     1.163077
# ...

# %% [markdown]
# Building model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=40)
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
#predict the value
pred=lm.predict(x_test)
print("Predicted result price:",pred)
print("actual price",y_test)
# Out:
# Predicted result price: [-0.27040383 -0.55164935 -0.22632218  0.43226058  1.77116     0.18439548
#   1.21699388 -0.43598991 -0.69338597 -0.92768633  1.08854743  1.0340934
#  -0.26437578  0.32860492  0.54051259 -0.70532954  0.21379869  0.56403025
#  -1.12508978  0.25706698 -0.64542992  1.06145828  0.34281523  1.33722593
#  -0.09855732 -0.5623873  -0.62469187  0.74330141 -1.17630965 -0.92802442
#   0.96782315 -0.85125907  0.69187142  0.72012099  0.7295503  -0.68972943
#   0.05840701  1.33168571 -0.20744266  1.62379465 -0.32248109 -1.38666101
#   1.30750714 -0.78698747  1.41188069  0.11375421  0.59007756  0.42277681
#   0.86776258 -0.35275212  1.85971074 -0.9933861  -0.92128311  0.60355415
#  -1.0440978   0.56183388  0.13031855  1.2406317  -0.83660868 -0.5381264
#   0.87383418 -1.16550996 -1.4210209  -1.05083512  1.11559995 -0.82304104]
# actual price 96    -0.376326
# 5     -1.396877
# 116   -0.274337
# 35    -0.154314
# 183    2.077382
# 160    0.154289
# 54     1.163077
# ...

# %%
import scipy.stats
from sklearn.metrics import mean_absolute_error
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean absolute error: 0.24249288752580261
# Mean squared error: 0.15261976602006339
# Root Mean squared error: 0.3906657983751117

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.8515525226850722

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
rfr.score(x_train,y_train)
# Out:
# 0.9963622870616123

# %%
rfr.score(x_test,y_test)
# Out:
# 0.9658891167895098

# %%
from sklearn import metrics
acc_R=metrics.r2_score(y_test,y_pred)
acc_R
# Out:
# 0.9658891167895098

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
y_pred=dtr.predict(x_test)
dtr.score(x_train,y_train)
acc_R=metrics.r2_score(y_test,y_pred)
acc_R
# Out:
# 0.9611394059822156

# %% [markdown]
# We are getting the best r2 score in RandomForestRegressor which is 0.965

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(lm,x,y,cv=5)
print("Cross validation score of Linear regression  model :",scr.mean())
# Out:
# Cross validation score of Linear regression  model : 0.9005787344238998

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(rfr,x,y,cv=5)
print("Cross validation score of Random Forest Regressor  model :",scr.mean())
# Out:
# Cross validation score of Random Forest Regressor  model : 0.9686158516784508

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(dtr,x,y,cv=5)
print("Cross validation score of Decision Tree Regressor  model :",scr.mean())
# Out:
# Cross validation score of Decision Tree Regressor  model : 0.9376767358923658

# %% [markdown]
# Minimum difference in score and cross validation score is for the random fores regressor model (0.0023)SO this is our best model

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators=[500,800,1500,2500,5000]
max_features=["auto","sqrt","log2"]
max_depth=[10,20,30,40,50]
min_samples_split=[2,5,10,15,20]
min_samples_leaf=[1,2,5,10,15]

# %%
grid_param={"n_estimators":n_estimators,"max_features":max_features,"max_depth":max_depth,"min_samples_split":min_samples_split,"min_samples_leaf":min_samples_leaf}

# %%
RFR=RandomForestRegressor(random_state=1)
RFR_random=RandomizedSearchCV(estimator=RFR,param_distributions=grid_param,n_iter=50,cv=4,verbose=3,random_state=42,n_jobs=-1)

# %%
RFR_random.fit(x_train,y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  5.1min finished
# RandomizedSearchCV(cv=4, estimator=RandomForestRegressor(random_state=1),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, 40, 50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10, 15],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [500, 800, 1500, 2500,
#                                                          5000]},
# ...

# %%
RFR_random.best_params_
# Out:
# {'n_estimators': 2500,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 50}

# %%
RFR_pred=RFR_random.best_estimator_.predict(x_test)

# %%
r2_score(y_test,RFR_pred)
# Out:
# 0.9433023818872981

# %%
import joblib   #dumping our model
joblib.dump(RFR_random.best_estimator_,"advertisingrfr.pkl")
# Out:
# ['advertisingrfr.pkl']
